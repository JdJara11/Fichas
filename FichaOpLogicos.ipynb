# %% [markdown]
# #### ESTRUCTURA 3
# # LÓGICA COMPUTACIONAL Y OPERADORES LÓGICOS
#
# 1. **Describa el por qué y para qué se utiliza.**

# %% [markdown]
# Se utilizan para evaluar condiciones y tomar decisiones en el código. Los operadores lógicos son and, or, y not. Nos dan como resultados valores de la tabla de verdad dando como resultado true o false.

# %% [markdown]
# 2. **Utiliza el código explicado en clase y agregue el/los ejemplos**

# %%
print(6 == 4)
print(4 < 8)
print(8 > 9)
print(9 <= 9)
print(10 >= 10)
print(12 != 12)
print("cama" == "cama")
print("mujer" != "hombre")
print(not True)

# %%
def truth_table_conjunction():
    print("p | q | p ∧ q (AND)")
    for p in [True, False]:
        for q in [True, False]:
            print(f"{p} | {q} | {p and q}")

def truth_table_disjunction():
    print("p | q | p ∨ q (OR)")
    for p in [True, False]:
        for q in [True, False]:
            print(f"{p} | {q} | {p or q}")

def truth_table_implication():
    print("p | q | p → q (not OR)")
    for p in [True, False]:
        for q in [True, False]:
            print(f"{p} | {q} | {not p or q}")

def truth_table_biconditional():
    print("p | q | p ↔ q (EQUAL)")
    for p in [True, False]:
        for q in [True, False]:
            print(f"{p} | {q} | {p == q}")

def truth_table_xor():
    print("p | q | p ⊕ q (NOT EQUAL)")
    for p in [True, False]:
        for q in [True, False]:
            print(f"{p} | {q} | {p != q}")

def truth_table_xand():
    print("p | q | p XAND q")
    print("-" * 15)
    for p in [True, False]:
        for q in [True, False]:
            a = p != q
            anot = not a
            print(f"{p} | {q} | {anot}")  # XAND es NOT XNOR
# Llamar las funciones para ver las tablas
truth_table_conjunction()
truth_table_disjunction()
truth_table_implication()
truth_table_biconditional()
truth_table_xor()
truth_table_xand()

# %% [markdown]
# 3. **Busque en internet un ejemplo y agreguelo internamente en el recuadro.**
#    - Utilice un editor de código en GOOGLE COLAB para lograrlo.

# %%
edad = 20
tiene_identificacion = True

# Evaluamos si la persona puede ingresar a un evento
puede_entrar = edad >= 18 and tiene_identificacion
print("¿Puede entrar al evento?", puede_entrar)
# Out:
# Ingrese su calificación del 1 al 100: 80
# Aprobado

# %% [markdown]
# 4. **BUSQUE UN ALGORITMO EN LINEA O EN EL LISTADO DE EJEMPLOS GENERADOS A CONTINUACIÓN QUE CORRESPONDA Y EXPLÍQUELO PASO A PASO**
# - Genere el link del audio y el link de GitHub.
#
#   🔗 **[GRADIO DEL AUDIO](#)**
#   INSERTE TODO ELLO EN GITHUB

# %%
q= 9<10
p= 8>7
print(q and p)

r = 8 < 4
e = 3 == 5
print(r or e)
